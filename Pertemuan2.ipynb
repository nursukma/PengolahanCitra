# %% [markdown]
# <a href="https://colab.research.google.com/github/nursukma/PengolahanCitra/blob/main/Pertemuan2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
#akses google drive
drive.mount('/content/drive')

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
import random

img = cv.imread('/content/drive/MyDrive/PengolahanCitra/images/kitten01.jpeg')
img3 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGBA),0) #konversi warna dari BGR ke RGB
# plt.imshow(img3)
# img4 = cv.resize(img3, (512,1024))
# img4 = cv.flip(img3, 0)
# fig = plt.figure(figsize=(10,10))
# ax = fig.add_subplot(111)
# ax.imshow(img4)

# img_gray = cv.imread('/content/drive/MyDrive/PengolahanCitra/images/kitten01.jpeg', cv.IMREAD_GRAYSCALE)
# plt.imshow(img_gray, cmap='magma')

# black_img = np.zeros(shape=(512,512,3), dtype=np.int16)

cv.rectangle(img3,pt1=(random.randint(0,500),random.randint(0,500))
,pt2=(random.randint(0,500),random.randint(0,500)),
color=(random.randint(0,255),random.randint(0,255),random.randint(0,255)),thickness=10)

cv.rectangle(img3,pt1=(random.randint(0,500),random.randint(0,500))
,pt2=(random.randint(0,500),random.randint(0,500)),
color=(random.randint(0,255),random.randint(0,255),random.randint(0,255)),thickness=10)

cv.rectangle(img3,pt1=(random.randint(0,500),random.randint(0,500))
,pt2=(random.randint(0,500),random.randint(0,500)),
color=(random.randint(0,255),random.randint(0,255),random.randint(0,255)),thickness=10)

cv.rectangle(img3,pt1=(random.randint(0,500),random.randint(0,500))
,pt2=(random.randint(0,500),random.randint(0,500)),
color=(random.randint(0,255),random.randint(0,255),random.randint(0,255)),thickness=10)

cv.rectangle(img3,pt1=(random.randint(0,500),random.randint(0,500))
,pt2=(random.randint(0,500),random.randint(0,500)),
color=(random.randint(0,255),random.randint(0,255),random.randint(0,255)),thickness=10)

plt.imshow(img3)

# plt.imshow(black_img, (cv.flip(black_img),0))
# cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=10)
# cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=10)
# cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=10)
# font = cv.FONT_HERSHEY_SIMPLEX
# cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
# plt.imshow(black_img)

# black_img = np.zeros(shape=(512,512,3), dtype=np.int32)
# vertices = np.array([[100,300], [200,200],[400,300],[200,400]], dtype=np.int32)
# pts = vertices.reshape((-1,1,2))
# cv.polylines(black_img,[pts],isClosed=True,color=(255,0,0),thickness=5)
# plt.imshow(black_img)
